# %%
import pandas as pd

# %%
gt_data = pd.read_csv("../data/ground_truth.txt", header=None)
pred_data = pd.read_csv("../data/detected_centLocs.csv")

# %%
gt_data.columns = ['frame', 'id', 'x', 'z', 'y']
pred_data.columns = ['frame', 'id', 'x', 'y']

# %%
pred_data
# Out:
#       frame    id         x         y
# 0         1  2621 -0.006936  0.025777
# 1         1  1543 -0.007307  0.028981
# 2         1  2622 -0.007240  0.026406
# 3         1   333 -0.007118  0.036660
# 4         1  4665 -0.006997  0.037185
# ...     ...   ...       ...       ...
# 3722     20  1452  0.007291  0.031908
# 3723     20  2199  0.007385  0.024724
# 3724     20     0  0.007372  0.035110
# 3725     20  2199  0.007482  0.024615
# 3726     20     0  0.007485  0.035303
#
# [3727 rows x 4 columns]

# %%
gt_data.describe()
# Out:
#              frame           id            x       z            y
# count  6451.000000  6451.000000  6451.000000  6451.0  6451.000000
# mean      9.989924  3162.071927    -0.000034     0.0     0.030206
# std       6.042977  1597.486627     0.004313     0.0     0.003779
# min       0.000000   274.000000    -0.007500     0.0     0.022502
# 25%       5.000000  1487.000000    -0.003819     0.0     0.027280
# 50%      10.000000  3177.000000     0.000148     0.0     0.030498
# 75%      15.000000  4776.000000     0.003551     0.0     0.033073
# max      20.000000  5115.000000     0.007498     0.0     0.037499

# %%
def get_id_map(df):
    id_map = {}
    id_counter = {}

    for row in df.iterrows():
        idx = row[1]['id']
        frame = row[1]['frame']
        if idx not in id_map:
            id_map[idx] = [frame]
            id_counter[idx] = 1
        else:
            id_map[idx].append(frame)
            id_counter[idx] += 1
    id_counter = {k:v for k, v in sorted(id_counter.items(), key=lambda item: item[1])}
    return id_map, id_counter

# %%
pred_id_map, pred_id_counter = get_id_map(pred_data)

# %%
pred_id_counter
# Out:
# {2363.0: 1,
#  1414.0: 1,
#  4769.0: 1,
#  4756.0: 1,
#  4456.0: 1,
#  1451.0: 1,
#  407.0: 1,
#  4969.0: 1,
#  5113.0: 1,
#  2627.0: 1,
#  874.0: 1,
#  1079.0: 2,
#  4782.0: 2,
#  2623.0: 2,
#  4122.0: 2,
#  4972.0: 2,
#  3605.0: 2,
#  4762.0: 3,
#  431.0: 3,
#  971.0: 3,
#  4795.0: 3,
#  467.0: 3,
#  421.0: 3,
#  4765.0: 3,
#  4789.0: 3,
#  4963.0: 3,
#  2534.0: 3,
#  3846.0: 3,
#  3990.0: 3,
#  2620.0: 3,
#  4775.0: 3,
#  3682.0: 4,
#  2586.0: 4,
#  2615.0: 4,
#  4771.0: 4,
#  4797.0: 4,
#  2604.0: 4,
#  2618.0: 5,
#  2579.0: 5,
#  3760.0: 5,
#  4794.0: 5,
#  1216.0: 5,
#  4433.0: 5,
#  1659.0: 5,
#  4807.0: 5,
#  3683.0: 5,
#  1356.0: 5,
#  4965.0: 5,
#  3763.0: 5,
#  2630.0: 5,
#  4754.0: 5,
#  3916.0: 5,
#  4966.0: 5,
#  4974.0: 5,
#  2597.0: 6,
#  852.0: 6,
#  412.0: 6,
#  2364.0: 6,
#  4607.0: 6,
#  4796.0: 6,
#  436.0: 6,
#  4949.0: 6,
#  4751.0: 6,
#  4790.0: 7,
#  414.0: 7,
#  2558.0: 7,
#  1445.0: 7,
#  1400.0: 7,
#  2225.0: 7,
#  2581.0: 7,
#  1478.0: 7,
#  4874.0: 7,
# ...

# %%
data = pd.read_csv("../data/detected_centLocs.csv")

# %%
data.head()
# Out:
#    frame  GTID         x         y
# 0      1  2621 -0.006936  0.025777
# 1      1  1543 -0.007307  0.028981
# 2      1  2622 -0.007240  0.026406
# 3      1   333 -0.007118  0.036660
# 4      1  4665 -0.006997  0.037185

# %%
def transform(df):
    df['x'] = 256+(df["x"] * 1000)*512/16 - 4
    df['y'] = 256 - (30- df["y"]*1000)*512/16 -4
    return df
data = transform(data)

# %%
data
# Out:
#       frame  GTID           x           y
# 0         1  2621   30.044864  116.855776
# 1         1  1543   18.174560  219.381472
# 2         1  2622   20.317312  137.000000
# 3         1   333   24.232128  465.124992
# 4         1  4665   28.104160  481.916672
# ...     ...   ...         ...         ...
# 3722     20  1452  485.320320  313.054688
# 3723     20  2199  488.328128   83.171872
# 3724     20     0  487.919104  415.511040
# 3725     20  2199  491.437504   79.687488
# 3726     20     0  491.531264  421.687488
#
# [3727 rows x 4 columns]

# %%
data['x1'] = data['x'] - 5
data['y1'] = data['y'] - 5
data['x2'] = data['x'] + 5
data['y2'] = data['y'] + 5
data['score'] = 1.0

# %%
data.head(1)
# Out:
#    frame  GTID          x           y         x1          y1         x2  \
# 0      1  2621  30.044864  116.855776  25.044864  111.855776  35.044864
#
#            y2  score
# 0  121.855776    1.0

# %%
# !pip install -r sort/requirements.txt

# %%
from sort.sort import Sort
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/t8/fx4n4x495t553jm07n5_9_bw0000gn/T/ipykernel_86103/1388065674.py in <module>
# ----> 1 from sort.sort import Sort
#
# ~/Desktop/Projects/ultra-sr-imaging/notebooks/sort/sort.py in <module>
#      29 import time
#      30 import argparse
# ---> 31 from filterpy.kalman import KalmanFilter
#      32
#      33 np.random.seed(0)
#
# ModuleNotFoundError: No module named 'filterpy'

# %%
def get_detections(df):
    coords = []

# %%
mot_tracker = Sort() 
track_bbs_ids = mot_tracker.update(detections)

# %%
# import matplotlib.pyplot as plt
# import matplotlib.patches as patches
# from PIL import Image

# im = Image.open('../data/frames/frame1.jpg')

# # Create figure and axes
# fig, ax = plt.subplots()
# centroid_x = 200
# centroid_y = 200
# xwidth = 50
# ywidth = 100

# # Display the image
# ax.imshow(im)

# # Create a Rectangle patch
# # rect = patches.Rectangle((50, 100), 40, 30, linewidth=1, edgecolor='r', facecolor='none')
# # 25.044864	111.855776	35.044864	121.855776	1.0
# # rect = patches.Rectangle((25, 111), 10, 10, linewidth=1, edgecolor='r', facecolor='none')
# rect = patches.Rectangle((centroid_x - xwidth/2, centroid_y - ywidth/2), xwidth, ywidth, linewidth=1, edgecolor='r', facecolor='none')
# # rect = patches.Rectangle((200, 200), 50, 100, linewidth=1, edgecolor='r', facecolor='none')

# # ((centroid_x - xwidth/2, centrod_y - ywidth/2), xwidth, ywidth


# # Add the patch to the Axes
# ax.add_patch(rect)

# plt.show()

# %%
# track_bbs_ids = mot_tracker.update(detections)

# %%
# here CCCx and CCCz are the pixel idx values. to convert into the units that the ground truth coordinates are in I used the following:
# CCCx = px.dx*CCCentroids(:,1) + px.mapX(1);
# CCCz = px.dz*CCCentroids(:,2) + px.mapZ(1);
# Saket Sripada10:24 PM
# px_dx = px_dy = 2.9296875e-05

# x = px_dx*CCCentroids(:,1) + px_mapX(1);
# z = px_dz*CCCentroids(:,2) + px_mapZ(1);
# here CCCx and CCCz are the pixel idx values. to convert into the units that the ground truth coordinates are in I used the above.
# So to go from ground truth coordinate units to pixel_idx, you might try to do the inverse as:
# CX_img = ( -px_mapX(1) + x_gt ) / px_dx
# CZ_img = ( -px_mapZ(1) + z_gt ) / px_dz

# %%
px_dx = px_dy = 2.9296875e-05

x = px_dx*CCCentroids(:,1) + px_mapX(1);
z = px_dz*CCCentroids(:,2) + px_mapZ(1);
here CCCx and CCCz are the pixel idx values. to convert into the units that the ground truth coordinates are in I used the above.
So to go from ground truth coordinate units to pixel_idx, you might try to do the inverse as:
CX_img = ( -px_mapX(1) + x_gt ) / px_dx
CZ_img = ( -px_mapZ(1) + z_gt ) / px_dz
